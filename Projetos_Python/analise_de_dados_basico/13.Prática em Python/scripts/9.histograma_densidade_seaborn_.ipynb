# %%
# Formação Cientista de Dados
# Histograma com densidade e seabord

# %%
# Importação das bibliotecas
import pandas as pd
import seaborn as srn
#pip install seaborn (executar no Anaconda Prompt)
import matplotlib.pyplot as plt

# %%
# Carregamento da base de dados
base = pd.read_csv('/TI/Python/FormacaoCD/13.Prática em Python/dados/trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Histograma com 10 divisões (bins) e com gráfico de densidade
srn.distplot(base.Volume, bins = 10, axlabel = 'Volume').set_title('Árvores')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\3008331521.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base.Volume, bins = 10, axlabel = 'Volume').set_title('Árvores')
# Text(0.5, 1.0, 'Árvores')

# %%
# Carregamento de outra base de dados
base2 = pd.read_csv('/TI/Python/FormacaoCD/13.Prática em Python/dados/chicken.csv')
base2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
# Criação de novo dataframe agrupando o atributo 'feed'
agrupado = base2.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# Novo dataframe somente para testar os filtros do pandas
teste = base2.loc[base2['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
# Histrograma considerando somente o valor 'horsebean'
srn.distplot(base2.loc[base2['feed'] == 'horsebean'].weight, hist = False).set_title('horsebean')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\3583896669.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'horsebean'].weight, hist = False).set_title('horsebean')
# Text(0.5, 1.0, 'horsebean')

# %%
# Histrograma considerando somente o valor 'casein'
srn.distplot(base2.loc[base2['feed'] == 'casein'].weight).set_title('casein')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\3846443402.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'casein'].weight).set_title('casein')
# Text(0.5, 1.0, 'casein')

# %%
# Histrograma considerando somente o valor 'linseed'
srn.distplot(base2.loc[base2['feed'] == 'linseed'].weight).set_title('linseed')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\4173270915.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'linseed'].weight).set_title('linseed')
# Text(0.5, 1.0, 'linseed')

# %%
# Histrograma considerando somente o valor 'meatmeal'
srn.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight).set_title('meatmeal')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\517653498.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight).set_title('meatmeal')
# Text(0.5, 1.0, 'meatmeal')

# %%
# Histrograma considerando somente o valor 'soybean'
srn.distplot(base2.loc[base2['feed'] == 'soybean'].weight).set_title('soybean')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\2399466648.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'soybean'].weight).set_title('soybean')
# Text(0.5, 1.0, 'soybean')

# %%
# Histrograma considerando somente o valor 'sunflower'
srn.distplot(base2.loc[base2['feed'] == 'sunflower'].weight).set_title('sunflower')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1656328084.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'sunflower'].weight).set_title('sunflower')
# Text(0.5, 1.0, 'sunflower')

# %%
#impresssão em gráfico 2 x 3
plt.figure()
plt.subplot(3,2,1)
srn.distplot(base2.loc[base2['feed'] == 'horsebean'].weight, hist = False).set_title('horsebean')
plt.subplot(3,2,2)
srn.distplot(base2.loc[base2['feed'] == 'casein'].weight).set_title('casein')
plt.subplot(3,2,3)
srn.distplot(base2.loc[base2['feed'] == 'linseed'].weight).set_title('linseed')
plt.subplot(3,2,4)
srn.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight).set_title('meatmeal')
plt.subplot(3,2,5)
srn.distplot(base2.loc[base2['feed'] == 'soybean'].weight).set_title('soybean')
plt.subplot(3,2,6)
srn.distplot(base2.loc[base2['feed'] == 'sunflower'].weight).set_title('sunflower')
#ajusta o layout para não haver sobreposição
plt.tight_layout()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1485638887.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'horsebean'].weight, hist = False).set_title('horsebean')
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1485638887.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'casein'].weight).set_title('casein')
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1485638887.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'linseed'].weight).set_title('linseed')
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1485638887.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight).set_title('meatmeal')
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1485638887.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'soybean'].weight).set_title('soybean')
# C:\Users\danie\AppData\Local\Temp\ipykernel_10788\1485638887.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(base2.loc[base2['feed'] == 'sunflower'].weight).set_title('sunflower')
